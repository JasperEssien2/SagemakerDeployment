# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# As our first example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there may be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2020-06-22 14:37:21--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  16.7MB/s    in 4.7s
#
# 2020-06-22 14:37:26 (16.9 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# '<br /><br />I\'m sure things didn\'t exactly go the same way in the real life of Homer Hickam as they did in the film adaptation of his book, Rocket Boys, but the movie "October Sky" (an anagram of the book\'s title) is good enough to stand alone. I have not read Hickam\'s memoirs, but I am still able to enjoy and understand their film adaptation. The film, directed by Joe Johnston and written by Lewis Colick, records the story of teenager Homer Hickam (Jake Gyllenhaal), beginning in October of 1957. It opens with the sound of a radio broadcast, bringing news of the Russian satellite Sputnik, the first artificial satellite in orbit. We see a images of a blue-gray town and its people: mostly miners working for the Olga Coal Company. One of the miners listens to the news on a hand-held radio as he enters the elevator shaft, but the signal is lost as he disappears into the darkness, losing sight of the starry sky above him. A melancholy violin tune fades with this image. We then get a jolt of Elvis on a car radio as words on the screen inform us of the setting: October 5, 1957, Coalwood, West Virginia. Homer and his buddies, Roy Lee Cook (William Lee Scott) and Sherman O\'Dell (Chad Lindberg), are talking about football tryouts. Football scholarships are the only way out of the town, and working in the mines, for these boys. "Why are the jocks the only ones who get to go to college," questions Homer. Roy Lee replies, "They\'re also the only ones who get the girls." Homer doesn\'t make it in football like his older brother, so he is destined for the mines, and to follow in his father\'s footsteps as mine foreman. Until he sees the dot of light streaking across the October sky. Then he wants to build a rocket. "I want to go into space," says Homer. After a disastrous attempt involving a primitive rocket and his mother\'s (Natalie Canerday) fence, Homer enlists the help of the nerdy Quentin Wilson (Chris Owen). Quentin asks Homer, "What do you want to know about rockets?" Homer quickly anwers, "Everything." His science teacher at Big Creek High School, Miss Frieda Riley (Laura Dern) greatly supports Homer, and the four boys work on building rockets in Homer\'s basement. His father, however, whose life is the mine, does not support him. John Hickam (Chris Cooper) believes that Homer shouldn\'t waste his time on the rockets, that the coal mines are all that matter. The coal from the mines is used to make steel, and without steel, the country would be nothing. The difficult relationship between Homer and his dad is one of the most poignant relationships I have ever seen in a film. Miss Riley introduces Homer to the idea of entering the local science fair, with a chance to go the nationals and win a college scholarship. "You can\'t just dream your way out of Coalwood," she tells Homer. Homer and his friends act upon their dreams by working constantly on the rockets, improving the models with each attempt. Despite the many attempts, the boys do not lose their determination. "What are the chances of us winning that science fair," O\'Dell asks Homer in one of their more despairing moments. "A million to one," answers Homer. "That good?" O\'Dell replies, "Well, why didn\'t you say so?" The music, composed by Mark Isham, conveys sadness and hope at the same time, especially sad at a point when Homer descends into the mine shaft and loses sight of the sky and his dreams of getting out of Coalwood. Rollicking 1950s\' rock and roll, including songs by The Coasters and Buddy Holly, occasionally pushes the instrumental pieces aside to create a light-hearted mood that contrasts the teenagers\' lives with the lives of the miners. The film, photographed by Fred Murphy, also uses colors to set moods and symbolize. The town of Coalwood, actually filmed in Tennessee, is washed with blues, grays, and browns. It\'s as if the grime from the coal sticks to everything- faces, clothes, houses, and roads. When a couple in a gleaming red convertible stops to  ...

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %%
# Preprocess data
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Read preprocessed data from cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.externals import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Read features from cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd

# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. Make sure that
#       val_X and val_y contain 10 000 entires while train_X and train_y contain the remaining 15 000 entries.

val_x = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
#       Make sure that the files you create are in the correct format.
pd.concat([val_y, val_x], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set text_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# WARNING:root:There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container,
                                    role,
                                   train_instance_count=1,
                                   train_instance_type='ml.m4.xlarge',
                                   output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                   sagemaker_session=session)


# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(max_depth=5,
                       eta=0.2,
                       gamma=4,
                       min_child_weight=6,
                       subsample=0.8,
                       silent=0,
                       objective='binary:logistic',
                       eary_stopping_rounds=10,
                       num_round=500)
# Out:
# WARNING:root:Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# WARNING:sagemaker:'s3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-06-22 14:39:05 Starting - Starting the training job...
# 2020-06-22 14:39:07 Starting - Launching requested ML instances......
# 2020-06-22 14:40:19 Starting - Preparing the instances for training......
# 2020-06-22 14:41:31 Downloading - Downloading input data...
# 2020-06-22 14:41:48 Training - Downloading the training image..Arguments: train
# [2020-06-22:14:42:09:INFO] Running standalone xgboost training.
# [2020-06-22:14:42:09:INFO] File size need to be processed in the node: 238.47mb. Available memory size in the node: 8486.76mb
# [2020-06-22:14:42:09:INFO] Determined delimiter of CSV input is ','
# [14:42:09] S3DistributionType set as FullyReplicated
# [14:42:11] 15000x5000 matrix with 75000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2020-06-22:14:42:11:INFO] Determined delimiter of CSV input is ','
# [14:42:11] S3DistributionType set as FullyReplicated
# [14:42:12] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [14:42:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 6 pruned nodes, max_depth=5
# [0]#011train-error:0.293133#011validation-error:0.3062
# [14:42:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 8 pruned nodes, max_depth=5
# [1]#011train-error:0.2772#011validation-error:0.2919
# [14:42:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 4 pruned nodes, max_depth=5
# [2]#011train-error:0.2768#011validation-error:0.2912
# [14:42:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 42 extra nodes, 8 pruned nodes, max_depth=5
# [3]#011train-error:0.268267#011validation-error:0.2831
#
# 2020-06-22 14:42:09 Training - Training image download completed. Training in progress.[14:42:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [4]#011train-error:0.265133#011validation-error:0.2817
# [14:42:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [5]#011train-error:0.2528#011validation-error:0.2683
# [14:42:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [6]#011train-error:0.247#011validation-error:0.2635
# [14:42:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 0 pruned nodes, max_depth=5
# [7]#011train-error:0.247133#011validation-error:0.2633
# [14:42:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 4 pruned nodes, max_depth=5
# [8]#011train-error:0.236733#011validation-error:0.2513
# [14:42:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 6 pruned nodes, max_depth=5
# [9]#011train-error:0.226467#011validation-error:0.2416
# [14:42:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 6 pruned nodes, max_depth=5
# [10]#011train-error:0.218933#011validation-error:0.2336
# [14:42:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [11]#011train-error:0.214067#011validation-error:0.2289
# [14:42:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 2 pruned nodes, max_depth=5
# [12]#011train-error:0.210733#011validation-error:0.225
# [14:42:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [13]#011train-error:0.209067#011validation-error:0.2238
# [14:42:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [14]#011train-error:0.206#011validation-error:0.2232
# [14:42:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [15]#011train-error:0.2036#011validation-error:0.2201
# [14:42:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [16]#011train-error:0.201133#011validation-error:0.2179
# [14:42:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [17]#011train-error:0.195933#011validation-error:0.2126
# [14:42:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [18]#011train-error:0.190933#011validation-error:0.2102
# [14:42:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 14 pruned nodes, max_depth=5
# [19]#011train-error:0.1876#011validation-error:0.208
# [14:42:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 6 pruned nodes, max_depth=5
# [20]#011train-error:0.185#011validation-error:0.2071
# [14:42:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 38 extra nodes, 12 pruned nodes, max_depth=5
# [21]#011train-error:0.181067#011validation-error:0.2041
# [14:42:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [22]#011train-error:0.178533#011validation-error:0.2035
# [14:42:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 8 pruned nodes, max_depth=5
# [23]#011train-error:0.177333#011validation-error:0.201
# [14:42:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [24]#011train-error:0.176333#011validation-error:0.2009
# [14:42:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [25]#011train-error:0.1752#011validation-error:0.197
# [14:42:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 2 pruned nodes, max_depth=5
# [26]#011train-error:0.1716#011validation-error:0.1961
# [14:42:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [27]#011train-error:0.1702#011validation-error:0.1943
# [14:42:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [28]#011train-error:0.167933#011validation-error:0.1932
# [14:42:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 6 pruned nodes, max_depth=5
# [29]#011train-error:0.1658#011validation-error:0.1929
# [14:42:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [30]#011train-error:0.164467#011validation-error:0.1915
# [14:42:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=5
# [31]#011train-error:0.162667#011validation-error:0.1889
# [14:42:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 12 pruned nodes, max_depth=5
# [32]#011train-error:0.161533#011validation-error:0.1859
# [14:42:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [33]#011train-error:0.160667#011validation-error:0.1862
# [14:42:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [34]#011train-error:0.159467#011validation-error:0.1846
# [14:43:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [35]#011train-error:0.158067#011validation-error:0.1847
# [14:43:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 12 pruned nodes, max_depth=5
# [36]#011train-error:0.155#011validation-error:0.1836
# [14:43:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [37]#011train-error:0.154733#011validation-error:0.1853
# [14:43:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 10 pruned nodes, max_depth=5
# [38]#011train-error:0.1526#011validation-error:0.1822
# [14:43:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [39]#011train-error:0.152067#011validation-error:0.1809
# [14:43:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [40]#011train-error:0.1512#011validation-error:0.1801
# [14:43:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 2 pruned nodes, max_depth=5
# [41]#011train-error:0.1502#011validation-error:0.1789
# [14:43:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 12 pruned nodes, max_depth=5
# [42]#011train-error:0.1492#011validation-error:0.1789
# [14:43:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 10 pruned nodes, max_depth=5
# [43]#011train-error:0.1484#011validation-error:0.1765
# [14:43:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 10 pruned nodes, max_depth=5
# [44]#011train-error:0.1476#011validation-error:0.1765
# [14:43:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [45]#011train-error:0.147133#011validation-error:0.1755
# [14:43:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [46]#011train-error:0.146#011validation-error:0.175
# [14:43:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [47]#011train-error:0.145133#011validation-error:0.1754
# [14:43:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [48]#011train-error:0.143067#011validation-error:0.1738
# [14:43:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 34 extra nodes, 10 pruned nodes, max_depth=5
# [49]#011train-error:0.141#011validation-error:0.1736
# [14:43:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [50]#011train-error:0.1404#011validation-error:0.1736
# [14:43:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 4 pruned nodes, max_depth=5
# [51]#011train-error:0.139133#011validation-error:0.1715
# [14:43:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [52]#011train-error:0.138333#011validation-error:0.1706
# [14:43:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 12 pruned nodes, max_depth=5
# [53]#011train-error:0.137467#011validation-error:0.1709
# [14:43:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [54]#011train-error:0.135267#011validation-error:0.1699
# [14:43:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [55]#011train-error:0.1344#011validation-error:0.1686
# [14:43:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [56]#011train-error:0.1332#011validation-error:0.1677
# [14:43:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [57]#011train-error:0.133133#011validation-error:0.1672
# [14:43:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [58]#011train-error:0.131867#011validation-error:0.1658
# [14:43:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 6 pruned nodes, max_depth=5
# [59]#011train-error:0.1312#011validation-error:0.1677
# [14:43:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 6 pruned nodes, max_depth=5
# [60]#011train-error:0.131#011validation-error:0.1667
# [14:43:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [61]#011train-error:0.131067#011validation-error:0.1649
# [14:43:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [62]#011train-error:0.1304#011validation-error:0.1636
# [14:43:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [63]#011train-error:0.1288#011validation-error:0.1638
# [14:43:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [64]#011train-error:0.127867#011validation-error:0.163
# [14:43:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [65]#011train-error:0.1266#011validation-error:0.1622
# [14:43:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 8 pruned nodes, max_depth=5
# [66]#011train-error:0.125467#011validation-error:0.1616
# [14:43:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [67]#011train-error:0.1258#011validation-error:0.161
# [14:43:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [68]#011train-error:0.124333#011validation-error:0.1606
# [14:43:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=5
# [69]#011train-error:0.1228#011validation-error:0.16
# [14:43:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 16 pruned nodes, max_depth=5
# [70]#011train-error:0.122467#011validation-error:0.1592
# [14:43:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=5
# [71]#011train-error:0.121733#011validation-error:0.1591
# [14:43:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 14 pruned nodes, max_depth=5
# [72]#011train-error:0.121267#011validation-error:0.1587
# [14:43:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [73]#011train-error:0.120733#011validation-error:0.1585
# [14:43:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [74]#011train-error:0.120733#011validation-error:0.1588
# [14:43:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [75]#011train-error:0.1204#011validation-error:0.1587
# [14:43:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [76]#011train-error:0.120267#011validation-error:0.1563
# [14:43:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 32 extra nodes, 12 pruned nodes, max_depth=5
# [77]#011train-error:0.119133#011validation-error:0.157
# [14:43:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [78]#011train-error:0.119133#011validation-error:0.1567
# [14:43:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [79]#011train-error:0.117667#011validation-error:0.1575
# [14:43:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [80]#011train-error:0.117733#011validation-error:0.1574
# [14:43:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [81]#011train-error:0.1182#011validation-error:0.1568
# [14:44:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [82]#011train-error:0.117533#011validation-error:0.1568
# [14:44:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [83]#011train-error:0.1172#011validation-error:0.1565
# [14:44:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [84]#011train-error:0.116533#011validation-error:0.1561
# [14:44:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [85]#011train-error:0.1162#011validation-error:0.1562
# [14:44:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [86]#011train-error:0.115867#011validation-error:0.1557
# [14:44:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [87]#011train-error:0.1154#011validation-error:0.1552
# [14:44:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [88]#011train-error:0.114067#011validation-error:0.1542
# [14:44:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [89]#011train-error:0.114067#011validation-error:0.1546
# [14:44:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [90]#011train-error:0.113333#011validation-error:0.1542
# [14:44:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [91]#011train-error:0.113133#011validation-error:0.1539
# [14:44:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [92]#011train-error:0.113067#011validation-error:0.1544
# [14:44:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [93]#011train-error:0.1128#011validation-error:0.1545
# [14:44:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [94]#011train-error:0.112267#011validation-error:0.1544
# [14:44:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [95]#011train-error:0.1118#011validation-error:0.1533
# [14:44:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [96]#011train-error:0.111467#011validation-error:0.1531
# [14:44:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 16 pruned nodes, max_depth=5
# [97]#011train-error:0.111333#011validation-error:0.1526
# [14:44:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 10 pruned nodes, max_depth=5
# [98]#011train-error:0.1102#011validation-error:0.1534
# [14:44:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 10 pruned nodes, max_depth=5
# [99]#011train-error:0.109533#011validation-error:0.1521
# [14:44:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [100]#011train-error:0.108667#011validation-error:0.1503
# [14:44:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [101]#011train-error:0.108133#011validation-error:0.1502
# [14:44:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [102]#011train-error:0.108067#011validation-error:0.1503
# [14:44:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [103]#011train-error:0.108#011validation-error:0.1506
# [14:44:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [104]#011train-error:0.107333#011validation-error:0.1497
# [14:44:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [105]#011train-error:0.1068#011validation-error:0.1496
# [14:44:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [106]#011train-error:0.105867#011validation-error:0.1499
# [14:44:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 16 pruned nodes, max_depth=5
# [107]#011train-error:0.105667#011validation-error:0.1488
# [14:44:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [108]#011train-error:0.105133#011validation-error:0.1489
# [14:44:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 8 pruned nodes, max_depth=5
# [109]#011train-error:0.104#011validation-error:0.1477
# [14:44:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [110]#011train-error:0.1034#011validation-error:0.1473
# [14:44:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [111]#011train-error:0.103267#011validation-error:0.1472
# [14:44:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [112]#011train-error:0.1034#011validation-error:0.1469
# [14:44:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [113]#011train-error:0.103067#011validation-error:0.1462
# [14:44:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [114]#011train-error:0.103#011validation-error:0.146
# [14:44:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [115]#011train-error:0.103#011validation-error:0.1462
# [14:44:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 8 pruned nodes, max_depth=5
# [116]#011train-error:0.1022#011validation-error:0.1459
# [14:44:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [117]#011train-error:0.101667#011validation-error:0.1457
# [14:44:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [118]#011train-error:0.1018#011validation-error:0.1447
# [14:44:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [119]#011train-error:0.1014#011validation-error:0.1452
# [14:44:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [120]#011train-error:0.099533#011validation-error:0.145
# [14:44:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [121]#011train-error:0.099267#011validation-error:0.1445
# [14:44:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [122]#011train-error:0.0986#011validation-error:0.145
# [14:44:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [123]#011train-error:0.098667#011validation-error:0.1446
# [14:44:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [124]#011train-error:0.098867#011validation-error:0.1448
# [14:44:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [125]#011train-error:0.097933#011validation-error:0.1446
# [14:44:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [126]#011train-error:0.097067#011validation-error:0.1438
# [14:44:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [127]#011train-error:0.097133#011validation-error:0.144
# [14:44:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [128]#011train-error:0.097267#011validation-error:0.1429
# [14:44:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [129]#011train-error:0.097267#011validation-error:0.1427
# [14:45:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 24 extra nodes, 4 pruned nodes, max_depth=5
# [130]#011train-error:0.0964#011validation-error:0.1424
# [14:45:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [131]#011train-error:0.0954#011validation-error:0.1426
# [14:45:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 36 extra nodes, 10 pruned nodes, max_depth=5
# [132]#011train-error:0.0956#011validation-error:0.1432
# [14:45:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [133]#011train-error:0.095667#011validation-error:0.1422
# [14:45:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [134]#011train-error:0.095733#011validation-error:0.1426
# [14:45:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [135]#011train-error:0.094333#011validation-error:0.1428
# [14:45:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [136]#011train-error:0.093933#011validation-error:0.1423
# [14:45:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [137]#011train-error:0.094133#011validation-error:0.1435
# [14:45:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [138]#011train-error:0.0944#011validation-error:0.1437
# [14:45:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 14 pruned nodes, max_depth=5
# [139]#011train-error:0.093867#011validation-error:0.1426
# [14:45:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [140]#011train-error:0.093667#011validation-error:0.141
# [14:45:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [141]#011train-error:0.0934#011validation-error:0.1409
# [14:45:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [142]#011train-error:0.093267#011validation-error:0.1414
# [14:45:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [143]#011train-error:0.093067#011validation-error:0.1409
# [14:45:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [144]#011train-error:0.093#011validation-error:0.1411
# [14:45:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [145]#011train-error:0.092667#011validation-error:0.1414
# [14:45:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [146]#011train-error:0.091467#011validation-error:0.1414
# [14:45:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [147]#011train-error:0.091333#011validation-error:0.1413
# [14:45:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [148]#011train-error:0.090533#011validation-error:0.1409
# [14:45:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 14 pruned nodes, max_depth=5
# [149]#011train-error:0.090733#011validation-error:0.14
# [14:45:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [150]#011train-error:0.090067#011validation-error:0.1401
# [14:45:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [151]#011train-error:0.0908#011validation-error:0.1405
# [14:45:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [152]#011train-error:0.090467#011validation-error:0.1404
# [14:45:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 16 pruned nodes, max_depth=5
# [153]#011train-error:0.090133#011validation-error:0.1405
# [14:45:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [154]#011train-error:0.0896#011validation-error:0.1406
# [14:45:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [155]#011train-error:0.0892#011validation-error:0.1403
# [14:45:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [156]#011train-error:0.0886#011validation-error:0.1398
# [14:45:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [157]#011train-error:0.089#011validation-error:0.1396
# [14:45:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [158]#011train-error:0.088533#011validation-error:0.1401
# [14:45:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [159]#011train-error:0.0884#011validation-error:0.1402
# [14:45:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [160]#011train-error:0.088267#011validation-error:0.1402
# [14:45:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [161]#011train-error:0.0876#011validation-error:0.1402
# [14:45:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 22 pruned nodes, max_depth=5
# [162]#011train-error:0.087267#011validation-error:0.1396
# [14:45:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [163]#011train-error:0.086733#011validation-error:0.1393
# [14:45:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [164]#011train-error:0.086533#011validation-error:0.1393
# [14:45:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [165]#011train-error:0.0864#011validation-error:0.1393
# [14:45:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [166]#011train-error:0.0862#011validation-error:0.1394
# [14:45:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [167]#011train-error:0.0856#011validation-error:0.1402
# [14:45:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [168]#011train-error:0.085267#011validation-error:0.1389
# [14:45:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [169]#011train-error:0.085133#011validation-error:0.1381
# [14:45:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 18 pruned nodes, max_depth=5
# [170]#011train-error:0.085733#011validation-error:0.1386
# [14:45:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [171]#011train-error:0.0854#011validation-error:0.1388
# [14:45:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [172]#011train-error:0.085267#011validation-error:0.1385
# [14:45:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [173]#011train-error:0.085067#011validation-error:0.1386
# [14:45:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [174]#011train-error:0.085133#011validation-error:0.1386
# [14:45:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [175]#011train-error:0.084733#011validation-error:0.1394
# [14:45:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [176]#011train-error:0.084933#011validation-error:0.1389
# [14:46:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [177]#011train-error:0.084067#011validation-error:0.1391
# [14:46:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [178]#011train-error:0.083933#011validation-error:0.1387
# [14:46:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [179]#011train-error:0.084133#011validation-error:0.1386
# [14:46:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [180]#011train-error:0.083667#011validation-error:0.1385
# [14:46:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [181]#011train-error:0.083467#011validation-error:0.1386
# [14:46:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [182]#011train-error:0.0836#011validation-error:0.1381
# [14:46:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [183]#011train-error:0.083#011validation-error:0.1381
# [14:46:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 10 pruned nodes, max_depth=5
# [184]#011train-error:0.083267#011validation-error:0.1384
# [14:46:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 6 pruned nodes, max_depth=5
# [185]#011train-error:0.082533#011validation-error:0.1372
# [14:46:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [186]#011train-error:0.082067#011validation-error:0.1375
# [14:46:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [187]#011train-error:0.082067#011validation-error:0.1374
# [14:46:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [188]#011train-error:0.081533#011validation-error:0.1367
# [14:46:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [189]#011train-error:0.081067#011validation-error:0.1365
# [14:46:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=5
# [190]#011train-error:0.081067#011validation-error:0.1361
# [14:46:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [191]#011train-error:0.080867#011validation-error:0.1362
# [14:46:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [192]#011train-error:0.080267#011validation-error:0.1358
# [14:46:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [193]#011train-error:0.0802#011validation-error:0.1355
# [14:46:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [194]#011train-error:0.079867#011validation-error:0.1353
# [14:46:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [195]#011train-error:0.080067#011validation-error:0.1351
# [14:46:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [196]#011train-error:0.079933#011validation-error:0.1358
# [14:46:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [197]#011train-error:0.079467#011validation-error:0.1358
# [14:46:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 16 pruned nodes, max_depth=5
# [198]#011train-error:0.079133#011validation-error:0.1354
# [14:46:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [199]#011train-error:0.078867#011validation-error:0.1359
# [14:46:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 14 pruned nodes, max_depth=5
# [200]#011train-error:0.078733#011validation-error:0.1355
# [14:46:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [201]#011train-error:0.0788#011validation-error:0.1355
# [14:46:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [202]#011train-error:0.0782#011validation-error:0.1355
# [14:46:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [203]#011train-error:0.078#011validation-error:0.1347
# [14:46:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 24 pruned nodes, max_depth=5
# [204]#011train-error:0.078#011validation-error:0.1348
# [14:46:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [205]#011train-error:0.078#011validation-error:0.1348
# [14:46:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [206]#011train-error:0.078467#011validation-error:0.1349
# [14:46:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [207]#011train-error:0.0776#011validation-error:0.135
# [14:46:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [208]#011train-error:0.077933#011validation-error:0.1344
# [14:46:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [209]#011train-error:0.0776#011validation-error:0.1347
# [14:46:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [210]#011train-error:0.077467#011validation-error:0.1348
# [14:46:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 8 pruned nodes, max_depth=5
# [211]#011train-error:0.077267#011validation-error:0.135
# [14:46:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [212]#011train-error:0.077333#011validation-error:0.1346
# [14:46:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [213]#011train-error:0.076467#011validation-error:0.1334
# [14:46:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [214]#011train-error:0.076133#011validation-error:0.1327
# [14:46:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 18 pruned nodes, max_depth=5
# [215]#011train-error:0.076#011validation-error:0.1325
# [14:46:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [216]#011train-error:0.075067#011validation-error:0.1323
# [14:46:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 10 pruned nodes, max_depth=5
# [217]#011train-error:0.075267#011validation-error:0.1319
# [14:46:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [218]#011train-error:0.075#011validation-error:0.1321
# [14:46:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [219]#011train-error:0.075067#011validation-error:0.1327
# [14:46:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [220]#011train-error:0.075#011validation-error:0.1323
# [14:46:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [221]#011train-error:0.075067#011validation-error:0.1321
# [14:46:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [222]#011train-error:0.0748#011validation-error:0.132
# [14:46:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [223]#011train-error:0.074467#011validation-error:0.1318
# [14:46:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [224]#011train-error:0.074333#011validation-error:0.1319
# [14:47:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [225]#011train-error:0.074#011validation-error:0.1315
# [14:47:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 8 pruned nodes, max_depth=5
# [226]#011train-error:0.073933#011validation-error:0.1312
# [14:47:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [227]#011train-error:0.073667#011validation-error:0.1317
# [14:47:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [228]#011train-error:0.0736#011validation-error:0.1309
# [14:47:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [229]#011train-error:0.073733#011validation-error:0.1307
# [14:47:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 14 pruned nodes, max_depth=5
# [230]#011train-error:0.0736#011validation-error:0.1308
# [14:47:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=5
# [231]#011train-error:0.073333#011validation-error:0.1318
# [14:47:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [232]#011train-error:0.073333#011validation-error:0.1318
# [14:47:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 6 pruned nodes, max_depth=5
# [233]#011train-error:0.072933#011validation-error:0.1309
# [14:47:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [234]#011train-error:0.072933#011validation-error:0.1307
# [14:47:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [235]#011train-error:0.0726#011validation-error:0.1312
# [14:47:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [236]#011train-error:0.072933#011validation-error:0.1307
# [14:47:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [237]#011train-error:0.072667#011validation-error:0.1307
# [14:47:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [238]#011train-error:0.072333#011validation-error:0.1309
# [14:47:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [239]#011train-error:0.072267#011validation-error:0.1302
# [14:47:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [240]#011train-error:0.071867#011validation-error:0.1305
# [14:47:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [241]#011train-error:0.071533#011validation-error:0.1306
# [14:47:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [242]#011train-error:0.071333#011validation-error:0.1307
# [14:47:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [243]#011train-error:0.0716#011validation-error:0.1306
# [14:47:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [244]#011train-error:0.071333#011validation-error:0.1303
# [14:47:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 14 pruned nodes, max_depth=5
# [245]#011train-error:0.071067#011validation-error:0.1311
# [14:47:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [246]#011train-error:0.071#011validation-error:0.1307
# [14:47:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [247]#011train-error:0.071#011validation-error:0.1304
# [14:47:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [248]#011train-error:0.070733#011validation-error:0.13
# [14:47:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [249]#011train-error:0.0706#011validation-error:0.1302
# [14:47:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [250]#011train-error:0.0702#011validation-error:0.13
# [14:47:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [251]#011train-error:0.0698#011validation-error:0.1301
# [14:47:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [252]#011train-error:0.069533#011validation-error:0.1297
# [14:47:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [253]#011train-error:0.069333#011validation-error:0.1305
# [14:47:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [254]#011train-error:0.069267#011validation-error:0.1305
# [14:47:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [255]#011train-error:0.069067#011validation-error:0.1308
# [14:47:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [256]#011train-error:0.069#011validation-error:0.1303
# [14:47:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [257]#011train-error:0.069#011validation-error:0.1302
# [14:47:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 12 pruned nodes, max_depth=5
# [258]#011train-error:0.0684#011validation-error:0.1302
# [14:47:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [259]#011train-error:0.068067#011validation-error:0.1301
# [14:47:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [260]#011train-error:0.0678#011validation-error:0.1303
# [14:47:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 2 pruned nodes, max_depth=5
# [261]#011train-error:0.0678#011validation-error:0.1297
# [14:47:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [262]#011train-error:0.067867#011validation-error:0.1297
# [14:47:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 16 pruned nodes, max_depth=5
# [263]#011train-error:0.068#011validation-error:0.1299
# [14:47:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [264]#011train-error:0.067933#011validation-error:0.1302
# [14:47:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [265]#011train-error:0.0678#011validation-error:0.1303
# [14:47:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 10 pruned nodes, max_depth=5
# [266]#011train-error:0.067867#011validation-error:0.1299
# [14:47:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [267]#011train-error:0.067267#011validation-error:0.13
# [14:47:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 12 pruned nodes, max_depth=5
# [268]#011train-error:0.067333#011validation-error:0.1306
# [14:47:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 14 pruned nodes, max_depth=3
# [269]#011train-error:0.0674#011validation-error:0.1301
# [14:47:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [270]#011train-error:0.067133#011validation-error:0.1311
# [14:47:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [271]#011train-error:0.066267#011validation-error:0.1311
# [14:48:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 10 pruned nodes, max_depth=5
# [272]#011train-error:0.066467#011validation-error:0.1314
# [14:48:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [273]#011train-error:0.066333#011validation-error:0.1317
# [14:48:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 20 pruned nodes, max_depth=5
# [274]#011train-error:0.0666#011validation-error:0.1319
# [14:48:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 12 pruned nodes, max_depth=5
# [275]#011train-error:0.065933#011validation-error:0.1322
# [14:48:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [276]#011train-error:0.065733#011validation-error:0.1323
# [14:48:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [277]#011train-error:0.065867#011validation-error:0.1316
# [14:48:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# ...
# [14:50:49] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [406]#011train-error:0.0556#011validation-error:0.1286
# [14:50:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=4
# [407]#011train-error:0.0554#011validation-error:0.1277
# [14:50:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [408]#011train-error:0.055867#011validation-error:0.1276
# [14:50:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 30 pruned nodes, max_depth=0
# [409]#011train-error:0.0558#011validation-error:0.1277
# [14:50:54] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 20 pruned nodes, max_depth=4
# [410]#011train-error:0.055533#011validation-error:0.1281
# [14:50:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=4
# [411]#011train-error:0.055733#011validation-error:0.1283
# [14:50:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [412]#011train-error:0.055867#011validation-error:0.1283
# [14:50:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [413]#011train-error:0.055867#011validation-error:0.1286
# [14:50:59] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [414]#011train-error:0.055867#011validation-error:0.1285
# [14:51:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [415]#011train-error:0.055467#011validation-error:0.1286
# [14:51:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [416]#011train-error:0.0556#011validation-error:0.1287
# [14:51:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 16 pruned nodes, max_depth=3
# [417]#011train-error:0.055467#011validation-error:0.1289
# [14:51:04] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [418]#011train-error:0.055533#011validation-error:0.1284
# [14:51:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [419]#011train-error:0.055533#011validation-error:0.1284
# [14:51:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 6 pruned nodes, max_depth=3
# [420]#011train-error:0.055467#011validation-error:0.1284
# [14:51:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 4 pruned nodes, max_depth=5
# [421]#011train-error:0.055667#011validation-error:0.1289
# [14:51:09] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [422]#011train-error:0.055733#011validation-error:0.1288
# [14:51:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [423]#011train-error:0.055733#011validation-error:0.1289
# [14:51:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [424]#011train-error:0.055733#011validation-error:0.1289
# [14:51:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 10 pruned nodes, max_depth=3
# [425]#011train-error:0.055467#011validation-error:0.1289
# [14:51:14] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [426]#011train-error:0.055467#011validation-error:0.1289
# [14:51:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=4
# [427]#011train-error:0.0554#011validation-error:0.1284
# [14:51:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 26 pruned nodes, max_depth=3
# [428]#011train-error:0.0554#011validation-error:0.1285
# [14:51:18] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 12 pruned nodes, max_depth=1
# [429]#011train-error:0.055333#011validation-error:0.1284
# [14:51:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [430]#011train-error:0.055333#011validation-error:0.1285
# [14:51:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [431]#011train-error:0.055467#011validation-error:0.1284
# [14:51:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [432]#011train-error:0.0548#011validation-error:0.129
# [14:51:23] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [433]#011train-error:0.054533#011validation-error:0.1292
# [14:51:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [434]#011train-error:0.054467#011validation-error:0.1303
# [14:51:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [435]#011train-error:0.054467#011validation-error:0.1303
# [14:51:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 12 pruned nodes, max_depth=1
# [436]#011train-error:0.054333#011validation-error:0.1306
# [14:51:28] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [437]#011train-error:0.0542#011validation-error:0.1308
# [14:51:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 14 pruned nodes, max_depth=5
# [438]#011train-error:0.053933#011validation-error:0.1304
# [14:51:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [439]#011train-error:0.053667#011validation-error:0.1301
# [14:51:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 12 pruned nodes, max_depth=5
# [440]#011train-error:0.053533#011validation-error:0.1307
# [14:51:33] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 16 pruned nodes, max_depth=2
# [441]#011train-error:0.053467#011validation-error:0.1308
# [14:51:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [442]#011train-error:0.053333#011validation-error:0.1309
# [14:51:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 6 pruned nodes, max_depth=5
# [443]#011train-error:0.053667#011validation-error:0.1306
# [14:51:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [444]#011train-error:0.053733#011validation-error:0.1305
# [14:51:38] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 8 pruned nodes, max_depth=5
# [445]#011train-error:0.053467#011validation-error:0.1303
# [14:51:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [446]#011train-error:0.053467#011validation-error:0.1302
# [14:51:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [447]#011train-error:0.053467#011validation-error:0.1302
# [14:51:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [448]#011train-error:0.053467#011validation-error:0.1302
# [14:51:43] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [449]#011train-error:0.0534#011validation-error:0.1301
# [14:51:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 8 pruned nodes, max_depth=5
# [450]#011train-error:0.053#011validation-error:0.13
# [14:51:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [451]#011train-error:0.053#011validation-error:0.1301
# [14:51:47] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [452]#011train-error:0.052867#011validation-error:0.1299
# [14:51:48] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [453]#011train-error:0.0528#011validation-error:0.1299
# [14:51:50] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 12 pruned nodes, max_depth=2
# [454]#011train-error:0.052867#011validation-error:0.1299
# [14:51:51] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [455]#011train-error:0.052867#011validation-error:0.13
# [14:51:52] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 14 pruned nodes, max_depth=4
# [456]#011train-error:0.0528#011validation-error:0.1303
# [14:51:53] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 12 pruned nodes, max_depth=1
# [457]#011train-error:0.052667#011validation-error:0.1301
# [14:51:55] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [458]#011train-error:0.052867#011validation-error:0.1296
# [14:51:56] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 22 pruned nodes, max_depth=2
# [459]#011train-error:0.0526#011validation-error:0.1297
# [14:51:57] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [460]#011train-error:0.0526#011validation-error:0.1297
# [14:51:58] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 12 pruned nodes, max_depth=4
# [461]#011train-error:0.0524#011validation-error:0.1293
# [14:52:00] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=4
# [462]#011train-error:0.052333#011validation-error:0.1291
# [14:52:01] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [463]#011train-error:0.052133#011validation-error:0.129
# [14:52:02] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [464]#011train-error:0.052333#011validation-error:0.129
# [14:52:03] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 20 pruned nodes, max_depth=2
# [465]#011train-error:0.052267#011validation-error:0.1289
# [14:52:05] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [466]#011train-error:0.052267#011validation-error:0.129
# [14:52:06] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 18 pruned nodes, max_depth=5
# [467]#011train-error:0.0526#011validation-error:0.1293
# [14:52:07] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 16 pruned nodes, max_depth=1
# [468]#011train-error:0.052533#011validation-error:0.1293
# [14:52:08] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [469]#011train-error:0.0524#011validation-error:0.1293
# [14:52:10] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 6 pruned nodes, max_depth=4
# [470]#011train-error:0.0524#011validation-error:0.1294
# [14:52:11] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 12 pruned nodes, max_depth=5
# [471]#011train-error:0.052067#011validation-error:0.1294
# [14:52:12] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 16 pruned nodes, max_depth=0
# [472]#011train-error:0.052133#011validation-error:0.1294
# [14:52:13] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [473]#011train-error:0.052133#011validation-error:0.1296
# [14:52:15] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 14 pruned nodes, max_depth=0
# [474]#011train-error:0.052133#011validation-error:0.1294
# [14:52:16] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [475]#011train-error:0.052133#011validation-error:0.1295
# [14:52:17] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 4 pruned nodes, max_depth=5
# [476]#011train-error:0.051733#011validation-error:0.1295
# [14:52:19] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 6 pruned nodes, max_depth=5
# [477]#011train-error:0.0518#011validation-error:0.1297
# [14:52:20] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [478]#011train-error:0.051733#011validation-error:0.1296
# [14:52:21] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 14 pruned nodes, max_depth=1
# [479]#011train-error:0.051733#011validation-error:0.1299
# [14:52:22] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [480]#011train-error:0.0518#011validation-error:0.1299
# [14:52:24] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [481]#011train-error:0.0518#011validation-error:0.1303
# [14:52:25] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 16 pruned nodes, max_depth=5
# [482]#011train-error:0.051467#011validation-error:0.1299
# [14:52:26] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [483]#011train-error:0.0516#011validation-error:0.1301
# [14:52:27] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 18 pruned nodes, max_depth=3
# [484]#011train-error:0.0512#011validation-error:0.1302
# [14:52:29] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [485]#011train-error:0.0512#011validation-error:0.1302
# [14:52:30] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 18 pruned nodes, max_depth=0
# [486]#011train-error:0.051333#011validation-error:0.13
# [14:52:31] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 12 pruned nodes, max_depth=2
# [487]#011train-error:0.051133#011validation-error:0.1302
# [14:52:32] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 26 pruned nodes, max_depth=4
# [488]#011train-error:0.051733#011validation-error:0.13
# [14:52:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 4 extra nodes, 16 pruned nodes, max_depth=2
# [489]#011train-error:0.052#011validation-error:0.13
# [14:52:35] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 2 extra nodes, 10 pruned nodes, max_depth=1
# [490]#011train-error:0.0518#011validation-error:0.13
# [14:52:36] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 18 pruned nodes, max_depth=5
# [491]#011train-error:0.051467#011validation-error:0.1295
# [14:52:37] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 12 pruned nodes, max_depth=0
# [492]#011train-error:0.051533#011validation-error:0.1294
# [14:52:39] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 22 pruned nodes, max_depth=0
# [493]#011train-error:0.051533#011validation-error:0.1294
# [14:52:40] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 10 pruned nodes, max_depth=3
# [494]#011train-error:0.0516#011validation-error:0.1294
# [14:52:41] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 10 pruned nodes, max_depth=5
# [495]#011train-error:0.051133#011validation-error:0.1299
# [14:52:42] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 20 pruned nodes, max_depth=0
# [496]#011train-error:0.051133#011validation-error:0.1299
# [14:52:44] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 10 pruned nodes, max_depth=5
# [497]#011train-error:0.051133#011validation-error:0.1298
# [14:52:45] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 10 pruned nodes, max_depth=0
# [498]#011train-error:0.051067#011validation-error:0.1298
# [14:52:46] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 8 pruned nodes, max_depth=5
# [499]#011train-error:0.050867#011validation-error:0.1299
#
# 2020-06-22 14:52:58 Uploading - Uploading generated training model
# 2020-06-22 14:52:58 Completed - Training job completed
# Training seconds: 687
# Billable seconds: 687

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.
xgb_transformer = xgb.transformer(instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# WARNING:sagemaker:Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, content_type='text/csv', split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# .....................Arguments: serve
# [2020-06-22 14:56:45 +0000] [1] [INFO] Starting gunicorn 19.7.1
# [2020-06-22 14:56:45 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2020-06-22 14:56:45 +0000] [1] [INFO] Using worker: gevent
# [2020-06-22 14:56:45 +0000] [37] [INFO] Booting worker with pid: 37
# [2020-06-22 14:56:45 +0000] [38] [INFO] Booting worker with pid: 38
# [2020-06-22 14:56:45 +0000] [39] [INFO] Booting worker with pid: 39
# [2020-06-22 14:56:45 +0000] [40] [INFO] Booting worker with pid: 40
# [2020-06-22:14:56:45:INFO] Model loaded successfully for worker : 38
# [2020-06-22:14:56:45:INFO] Model loaded successfully for worker : 37
# [2020-06-22:14:56:45:INFO] Model loaded successfully for worker : 39
# [2020-06-22:14:56:45:INFO] Model loaded successfully for worker : 40
# [2020-06-22:14:57:10:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:10:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:10:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:10:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:10:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:10:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:10:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:11:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:11:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:10:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:10:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:10:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:10:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:10:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:11:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:11:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:12:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:12:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:13:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:13:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:12:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:12:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:13:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:13:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:13:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:13:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:13:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:13:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:13:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:13:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:13:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:13:INFO] Determined delimiter of CSV input is ','
# 2020-06-22T14:57:07.728:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [2020-06-22:14:57:15:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:15:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:16:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:15:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:15:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:16:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:16:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:16:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:17:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:17:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:17:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:17:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:17:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:17:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:17:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:17:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:18:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:18:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:18:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:18:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:18:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:18:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:18:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:18:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:20:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:20:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:21:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:21:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:20:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:20:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:21:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:21:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:22:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:22:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:22:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:22:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:23:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:23:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:22:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:22:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:22:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:22:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:23:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:23:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:23:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:23:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:23:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:23:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:25:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:25:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:25:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:25:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:25:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:25:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:26:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:26:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:25:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:25:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:25:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:25:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:25:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:25:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:26:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:26:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:27:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:27:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:27:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:27:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:28:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:28:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:27:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:27:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:27:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:27:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:28:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:28:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:28:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:28:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:28:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:28:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:30:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:30:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:32:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:32:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:32:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:32:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:32:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:32:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:32:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:32:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:32:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:32:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:32:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:32:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:33:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:33:INFO] Sniff delimiter as ','
# [2020-06-22:14:57:33:INFO] Determined delimiter of CSV input is ','
# [2020-06-22:14:57:33:INFO] Determined delimiter of CSV input is ','

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-us-west-2-910150640493/xgboost-2020-06-22-14-53-25-389/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.87232

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
